# %% [markdown]
# ## Team Data_Deciphers

# %% [markdown]
# ### Time Series Forecasting (with original dataset)

# %%
# import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools

import statsmodels.graphics.tsaplots as tsa
import statsmodels.tsa.stattools as ts

from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# read data
data_sales=pd.read_csv('Training-Data-Sets.csv', index_col=0)

# %%
# doing some sanity check ok data
data_sales.head()
# Out:
#               EQ  Social_Search_Impressions  Social_Search_Working_cost  \
# Day
# 1     718.458667                   22256928                       56812
# 2      25.521137                    4239408                      105695
# 3     268.288044                    6708500                       87686
# 4     209.071599                   36835247                       70791
# 5    3482.169185                   23693467                       75610
#
#      Digital_Impressions  Digital_Working_cost  Print_Impressions.Ads40  \
# Day
# 1                7724107                238700                   151438
# 2                5844288                188902                   264008
# 3               13008485                 19704                   150505
# 4                2520814                200111                   253458
# 5                9276779                 65532                   278877
#
#      Print_Working_Cost.Ads50  OOH_Impressions  OOH_Working_Cost  SOS_pct  \
# Day
# 1                        1044        112229070           2133614        5
# 2                      113582        284597324           1719318       38
# 3                       38501        807781054           1569740        9
# 4                       53719        667441334            922723        9
# 5                       95178         74045467           1834970       26
#
#      ...  Magazine_Impressions_pct  TV_GRP  Competitor1_RPI  Competitor2_RPI  \
# Day  ...
# 1    ...                     54.17   16.46           105.71            36.13
# 2    ...                     65.79   15.64           111.79            43.31
# 3    ...                     45.08   23.91           110.15            38.26
# 4    ...                     75.24   13.06           116.74            39.37
# 5    ...                     56.85   40.72           115.18            36.85
#
#      Competitor3_RPI  Competitor4_RPI  EQ_Category  EQ_Subcategory  \
# Day
# 1              46.36            71.83      5420048          475559
# 2              47.58            67.90     12155631          371540
# 3              49.26            72.70     11939870          225984
# 4              44.21            73.01      7045541          551342
# 5              45.46            75.84     11488805          254143
#
#      pct_PromoMarketDollars_Subcategory  RPI_Subcategory
# Day
# 1                                0.3766            45.77
# 2                                0.2515            35.02
# 3                                0.3679            46.22
# 4                                0.0504            38.10
# 5                                0.2219            39.16
#
# [5 rows x 38 columns]

# %%
# we have to forecast data for 28 days period, we have given data on daily basis, so aggregating data for 28 days
train_grouped = data_sales.groupby(np.arange(len(data_sales)) // 28).mean()
train_grouped.head()
# Out:
#             EQ  Social_Search_Impressions  Social_Search_Working_cost  \
# 0   667.858556               1.769089e+07                75855.928571
# 1   277.717426               1.557197e+07                60078.857143
# 2  1083.904871               2.318512e+07                70334.857143
# 3   597.319170               1.870334e+07                66125.464286
# 4  1269.848862               2.087961e+07                58869.464286
#
#    Digital_Impressions  Digital_Working_cost  Print_Impressions.Ads40  \
# 0         6.349730e+06         199714.321429            207294.071429
# 1         6.647341e+06         201148.107143            205014.750000
# 2         6.204214e+06         212023.464286            203763.178571
# 3         7.125146e+06         191658.392857            205844.357143
# 4         5.672213e+06         207559.000000            196776.178571
#
#    Print_Working_Cost.Ads50  OOH_Impressions  OOH_Working_Cost    SOS_pct  \
# 0             106157.750000     3.699968e+08      1.910145e+06  22.357143
# 1              97501.678571     4.518553e+08      1.792867e+06  27.750000
# 2             119702.392857     5.777184e+08      1.992896e+06  24.571429
# 3             110357.464286     4.228509e+08      2.050156e+06  29.464286
# 4             105472.464286     4.734685e+08      2.088812e+06  24.071429
#
#    ...  Magazine_Impressions_pct     TV_GRP  Competitor1_RPI  Competitor2_RPI  \
# 0  ...                 51.130357  29.811071       107.341429        38.613929
# 1  ...                 51.773929  28.815000       104.888929        37.431429
# 2  ...                 52.857500  31.518929       104.847143        39.231071
# 3  ...                 47.435357  28.932500       109.611429        38.054643
# 4  ...                 49.931786  27.661786       105.889643        38.928571
#
#    Competitor3_RPI  Competitor4_RPI   EQ_Category  EQ_Subcategory  \
# 0        45.584643        70.815714  7.156285e+06   511652.464286
# 1        46.185357        69.854286  7.155017e+06   526414.464286
# 2        46.289286        70.239286  6.219402e+06   493792.357143
# 3        46.428929        69.806786  6.173164e+06   558087.892857
# 4        46.140714        71.021786  6.840374e+06   585072.857143
#
#    pct_PromoMarketDollars_Subcategory  RPI_Subcategory
# 0                            0.233807        39.577857
# 1                            0.218829        40.216071
# 2                            0.233504        41.722500
# 3                            0.226993        41.577857
# 4                            0.222521        38.733214
#
# [5 rows x 38 columns]

# %%
#plt.plot(abc.index, abc['EQ'])
# lets plot the aggregated time series data and check for stationarity of the series

plt.figure(figsize=(14,6))
plt.plot(train_grouped[['EQ']], label='train')
plt.xlabel('Period (4 weeks)')
plt.ylabel('sales')
plt.title('Sales/Period', fontsize=14)
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %% [markdown]
# There is no trend in data and it looks like a pure white noice.
#
# Let's plot ACF and PACF grapgs to check auto correation lagged values

# %%
#ACF and PACF
tsa.plot_acf(train_grouped[['EQ']],lags=20)
tsa.plot_pacf(train_grouped[['EQ']],lags=20)
plt.show()

# %%
# define p d and q parameters to take any values betweem 0 and 2
p=d=q= range(0,2)

# generate all the different combinations of P,D, and Q

pdq=list(itertools.product(p,d,q))

# geberate all the different combinations of seasonality p,d and q triplets

seasonal_pdq=[(x[0],x[1],x[2], 13) for x in list(itertools.product(p,d,q))]

print("Example of param components for seasonal ARIMA")
print('SARIMAX: {} x {}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[2],seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[3],seasonal_pdq[3]))
# Out:
# Example of param components for seasonal ARIMA
# SARIMAX: (0, 0, 1) x (0, 0, 1, 13)
# SARIMAX: (0, 1, 0) x (0, 1, 0, 13)
# SARIMAX: (0, 1, 1) x (0, 1, 1, 13)

# %%
train=np.log(train_grouped['EQ'])

# %%
sns.distplot(train_grouped['EQ'])
plt.show()

# %%
for param_seasonal in seasonal_pdq:
    print(param_seasonal)
# Out:
# (0, 0, 0, 13)
# (0, 0, 1, 13)
# (0, 1, 0, 13)
# (0, 1, 1, 13)
# (1, 0, 0, 13)
# (1, 0, 1, 13)
# (1, 1, 0, 13)
# (1, 1, 1, 13)

# %%
# iteration of all the combinations of p, d and q

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod=sm.tsa.statespace.SARIMAX(train,
                                         order=param,
                                         seasonal_order=param_seasonal,
                                         enforce_stationarity= False,
                                         enforce_invertibility=False)
            results= mod.fit()
            
            print("ARIMA{} x {}13 - AIC:{} - BIC:{}".format(param,param_seasonal,round(results.aic,4),round(results.bic,4)))
        except :
            continue
# Out:
# ARIMA(0, 0, 0) x (0, 0, 0, 13)13 - AIC:2806.0601 - BIC:2810.1192
# ARIMA(0, 0, 0) x (0, 0, 1, 13)13 - AIC:2238.5528 - BIC:2246.6094
# ARIMA(0, 0, 0) x (0, 1, 0, 13)13 - AIC:618.0967 - BIC:622.1249
# ARIMA(0, 0, 0) x (0, 1, 1, 13)13 - AIC:358.8221 - BIC:366.815
# ARIMA(0, 0, 0) x (1, 0, 0, 13)13 - AIC:619.3831 - BIC:627.4445
# ARIMA(0, 0, 0) x (1, 0, 1, 13)13 - AIC:381.3469 - BIC:393.4317
# ARIMA(0, 0, 0) x (1, 1, 0, 13)13 - AIC:449.1287 - BIC:457.1266
# ARIMA(0, 0, 0) x (1, 1, 1, 13)13 - AIC:363.3637 - BIC:375.3531
# ARIMA(0, 0, 1) x (0, 0, 0, 13)13 - AIC:2272.9517 - BIC:2281.0653
# ARIMA(0, 0, 1) x (0, 0, 1, 13)13 - AIC:1865.0049 - BIC:1877.0825
# ARIMA(0, 0, 1) x (0, 1, 0, 13)13 - AIC:615.7015 - BIC:623.7533
# ARIMA(0, 0, 1) x (0, 1, 1, 13)13 - AIC:352.975 - BIC:364.9569
# ARIMA(0, 0, 1) x (1, 0, 0, 13)13 - AIC:619.298 - BIC:631.39
# ARIMA(0, 0, 1) x (1, 0, 1, 13)13 - AIC:627.877 - BIC:643.9805
# ARIMA(0, 0, 1) x (1, 1, 0, 13)13 - AIC:447.4905 - BIC:459.4873
# ARIMA(0, 0, 1) x (1, 1, 1, 13)13 - AIC:356.4625 - BIC:372.4383
# ARIMA(0, 1, 0) x (0, 0, 0, 13)13 - AIC:588.6367 - BIC:592.6935
# ARIMA(0, 1, 0) x (0, 0, 1, 13)13 - AIC:557.3258 - BIC:565.3776
# ARIMA(0, 1, 0) x (0, 1, 0, 13)13 - AIC:872.5785 - BIC:876.6043
# ARIMA(0, 1, 0) x (0, 1, 1, 13)13 - AIC:582.3567 - BIC:590.3447
# ARIMA(0, 1, 0) x (1, 0, 0, 13)13 - AIC:557.9302 - BIC:565.9868
# ARIMA(0, 1, 0) x (1, 0, 1, 13)13 - AIC:558.8181 - BIC:570.8957
# ARIMA(0, 1, 0) x (1, 1, 0, 13)13 - AIC:686.52 - BIC:694.5129
# ARIMA(0, 1, 0) x (1, 1, 1, 13)13 - AIC:582.476 - BIC:594.4579
# ARIMA(0, 1, 1) x (0, 0, 0, 13)13 - AIC:343.6425 - BIC:351.7513
# ARIMA(0, 1, 1) x (0, 0, 1, 13)13 - AIC:334.3583 - BIC:346.4286
# ARIMA(0, 1, 1) x (0, 1, 0, 13)13 - AIC:615.2159 - BIC:623.2628
# ARIMA(0, 1, 1) x (0, 1, 1, 13)13 - AIC:362.5249 - BIC:374.4993
# ARIMA(0, 1, 1) x (1, 0, 0, 13)13 - AIC:337.0737 - BIC:349.1586
# ARIMA(0, 1, 1) x (1, 0, 1, 13)13 - AIC:335.4863 - BIC:351.5801
# ARIMA(0, 1, 1) x (1, 1, 0, 13)13 - AIC:456.882 - BIC:468.8713
# ARIMA(0, 1, 1) x (1, 1, 1, 13)13 - AIC:369.3369 - BIC:385.3028
# ARIMA(1, 0, 0) x (0, 0, 0, 13)13 - AIC:593.66 - BIC:601.7783
# ARIMA(1, 0, 0) x (0, 0, 1, 13)13 - AIC:559.4859 - BIC:571.5707
# ARIMA(1, 0, 0) x (0, 1, 0, 13)13 - AIC:617.954 - BIC:626.0105
# ARIMA(1, 0, 0) x (0, 1, 1, 13)13 - AIC:355.2285 - BIC:367.2179
# ARIMA(1, 0, 0) x (1, 0, 0, 13)13 - AIC:559.3216 - BIC:571.4065
# ARIMA(1, 0, 0) x (1, 0, 1, 13)13 - AIC:561.2611 - BIC:577.3742
# ARIMA(1, 0, 0) x (1, 1, 0, 13)13 - AIC:447.0613 - BIC:459.0506
# ARIMA(1, 0, 0) x (1, 1, 1, 13)13 - AIC:358.5574 - BIC:374.5432
# ARIMA(1, 0, 1) x (0, 0, 0, 13)13 - AIC:352.8727 - BIC:365.043
# ARIMA(1, 0, 1) x (0, 0, 1, 13)13 - AIC:338.6608 - BIC:354.7642
# ARIMA(1, 0, 1) x (0, 1, 0, 13)13 - AIC:616.5637 - BIC:628.6413
# ARIMA(1, 0, 1) x (0, 1, 1, 13)13 - AIC:353.3205 - BIC:369.2963
# ARIMA(1, 0, 1) x (1, 0, 0, 13)13 - AIC:338.933 - BIC:355.0461
# ARIMA(1, 0, 1) x (1, 0, 1, 13)13 - AIC:341.6147 - BIC:361.744
# ARIMA(1, 0, 1) x (1, 1, 0, 13)13 - AIC:448.9532 - BIC:464.939
# ARIMA(1, 0, 1) x (1, 1, 1, 13)13 - AIC:358.2592 - BIC:378.229
# ARIMA(1, 1, 0) x (0, 0, 0, 13)13 - AIC:488.5249 - BIC:496.6385
# ARIMA(1, 1, 0) x (0, 0, 1, 13)13 - AIC:471.0154 - BIC:483.093
# ARIMA(1, 1, 0) x (0, 1, 0, 13)13 - AIC:763.6172 - BIC:771.669
# ARIMA(1, 1, 0) x (0, 1, 1, 13)13 - AIC:494.0654 - BIC:506.0473
# ARIMA(1, 1, 0) x (1, 0, 0, 13)13 - AIC:471.0081 - BIC:483.0857
# ARIMA(1, 1, 0) x (1, 0, 1, 13)13 - AIC:472.8935 - BIC:488.997
# ARIMA(1, 1, 0) x (1, 1, 0, 13)13 - AIC:587.5264 - BIC:599.5083
# ARIMA(1, 1, 0) x (1, 1, 1, 13)13 - AIC:498.1617 - BIC:514.1375
# ARIMA(1, 1, 1) x (0, 0, 0, 13)13 - AIC:339.8463 - BIC:352.0097
# ARIMA(1, 1, 1) x (0, 0, 1, 13)13 - AIC:329.5728 - BIC:345.6666
# ARIMA(1, 1, 1) x (0, 1, 0, 13)13 - AIC:614.525 - BIC:626.5954
# ARIMA(1, 1, 1) x (0, 1, 1, 13)13 - AIC:359.6535 - BIC:375.6193
# ARIMA(1, 1, 1) x (1, 0, 0, 13)13 - AIC:331.0654 - BIC:347.1688
# ARIMA(1, 1, 1) x (1, 0, 1, 13)13 - AIC:331.0701 - BIC:351.1873
# ARIMA(1, 1, 1) x (1, 1, 0, 13)13 - AIC:450.0649 - BIC:466.0407
# ARIMA(1, 1, 1) x (1, 1, 1, 13)13 - AIC:366.1606 - BIC:386.1179

# %%
# by using best P D Q values for order and seasonal order, building the final forcast model
arima_model_train = sm.tsa.statespace.SARIMAX(train,
                                             order=(3,2,1),
                                             seasonal_order= (2, 2, 2, 13),
                                              enforce_stationarity= False,
                                         enforce_invertibility=False)
results_arima_train= arima_model_train.fit()

print(results_arima_train.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6241      0.056    -11.109      0.000      -0.734      -0.514
# ar.L2         -0.4058      0.070     -5.788      0.000      -0.543      -0.268
# ar.L3         -0.1998      0.055     -3.618      0.000      -0.308      -0.092
# ma.L1         -1.0000    144.135     -0.007      0.994    -283.500     281.500
# ar.S.L13      -0.8305      0.147     -5.659      0.000      -1.118      -0.543
# ar.S.L26      -0.3655      0.084     -4.368      0.000      -0.529      -0.201
# ma.S.L13      -0.8620    378.839     -0.002      0.998    -743.373     741.649
# ma.S.L26      -0.1380     52.230     -0.003      0.998    -102.506     102.230
# sigma2         0.1972     74.275      0.003      0.998    -145.380     145.774
# ==============================================================================

# %%
# predict value based on ARIMA model

pred_arima_train = results_arima_train.get_prediction(dynamic=False)
pred_arima_train_ci = pred_arima_train.conf_int()

# %%
# plotting actual vs predicted

plt.figure(figsize=(14,6))
plot1=train.plot(label='observed')
pred_arima_train.predicted_mean.plot(ax=plot1,label='predicted (ARIMA)')


plt.xlabel('Period')
plt.ylabel('Sales')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Lets check the stationarity of the residual series

# %% [markdown]
# ### Stationarity tests

# %%
residual = pred_arima_train.predicted_mean- train

# %%
# Augmented Dickey-Fuller test
import statsmodels.tsa.stattools as ts
residual1= residual [~residual.isnull()]

adf_test= ts.adfuller(residual1,autolag='AIC')

print('ADF Statistic: %f' % adf_test[0])
print('P-value : %f'% adf_test[1])
print('Critical Values : ')

for key, values in adf_test[4].items():
    print('\t%s: %.3f' % (key, values))
# Out:
# ADF Statistic: -6.890316
# P-value : 0.000000
# Critical Values :
# 	1%: -3.446
# 	5%: -2.869
# 	10%: -2.571

# %% [markdown]
# Test statistc is less than Critical values so we can conclude that residual series is stationary or pure white noise.
# p-value obtained by the ADF test is less than 0.05 so the residual series is pure white noice.

# %%
#KPSS (Kwiatkowski-Phillips-Schmidt-Shin) Test
kpss_test= ts.kpss(residual1,regression='c', store=False)

print('KPSS Statistic: %f' % kpss_test[0])
print('P-value : %f'% kpss_test[1])
print('Critical Values : ')

for key, values in kpss_test[3].items():
    print('\t%s: %.3f' % (key, values))
# Out:
# KPSS Statistic: 0.039351
# P-value : 0.100000
# Critical Values :
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739

# %% [markdown]
# Test statistc is less than Critical values so we can conclude that residual series is stationary or pure white noice.
# p-value obtained by the ADF test is less than 0.05 so the residual series is pure white noice.

# %%
# Calcualte MAPE on train data
arima_pred_train= np.exp(pred_arima_train.predicted_mean)
n= len(arima_pred_train)
total=0
for i in range(n):
    total=total+np.absolute((100*(np.exp(train.iloc[i]) - arima_pred_train.iloc[i])/np.exp(train.iloc[i])))
    
MAPE=total/n
print("MAPE Value :  {}".format(round(MAPE,4)))
# Out:
# MAPE Value :  168.4973

# %%
# plotting rge predicted diagnostics
results_arima_train.plot_diagnostics(figsize=(15,8))
plt.show()

# %%
# Reading test data, and forecating for 39 time periods
pred_arima = results_arima_train.forecast(steps=39)
test=pd.read_excel('Test dataset v1.xlsx', index_col=0)

# %%
# taking out sales data from test
test_a=test['EQ']
test_a1=test_a.reset_index().drop('Period',1)
pred_arima1=np.exp(pred_arima.reset_index().drop('index',1))

# %%
# plotting forecated sales vs Actual sales

plt.figure(figsize=(14,6))
plot1=test_a1.plot(label='observed')
pred_arima1.plot(ax=plot1,label='predicted (ARIMA)')


plt.xlabel('Period (4 weeks)')
plt.ylabel('Sales')
plt.legend(loc='best')
plt.show()

# %%
# Calculating MAPE on test
arima_pred_test= pred_arima1[0]
n= len(arima_pred_test)
total=0
for i in range(n):
    total=total+np.absolute((100*(test_a1.iloc[i] - arima_pred_test.iloc[i])/test_a1.iloc[i]))
    
MAPE=total/n
print("MAPE Value :  {}".format(round(MAPE,4)))
# Out:
# MAPE Value :  EQ    26.3445
# dtype: float64

# %%
print(test_a1.iloc[0] - arima_pred_test.iloc[0])
# Out:
# EQ    69.781375
# Name: 0, dtype: float64
